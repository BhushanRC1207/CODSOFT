# %%
# import required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('IMDb Movies India.csv',encoding=('ISO-8859-1'))

# %%
df.shape
# Out:
# (15509, 10)

# %%
df.head(10)
# Out:
#                                  Name    Year Duration  \
# 0                                         NaN      NaN
# 1  #Gadhvi (He thought he was Gandhi)  (2019)  109 min
# 2                         #Homecoming  (2021)   90 min
# 3                             #Yaaram  (2019)  110 min
# 4                   ...And Once Again  (2010)  105 min
# 5                ...Aur Pyaar Ho Gaya  (1997)  147 min
# 6                           ...Yahaan  (2005)  142 min
# 7                      .in for Motion  (2008)   59 min
# 8                  ?: A Question Mark  (2012)   82 min
# 9                            @Andheri  (2014)  116 min
#
#                        Genre  Rating  Votes            Director  \
# 0                      Drama     NaN    NaN       J.S. Randhawa
# 1                      Drama     7.0      8       Gaurav Bakshi
# 2             Drama, Musical     NaN    NaN  Soumyajit Majumdar
# 3            Comedy, Romance     4.4     35          Ovais Khan
# ...

# %%
df.tail(10)
# Out:
#                       Name    Year Duration                 Genre  Rating  \
# 15499        Zulm Ka Jawab  (1995)      NaN                Action     NaN
# 15500      Zulm Ka Muqabla  (1993)      NaN                Action     NaN
# 15501      Zulm Ki Hukumat  (1992)      NaN  Action, Crime, Drama     5.3
# 15502        Zulm Ki Pukar  (1979)      NaN                Action     NaN
# 15503      Zulm Ki Zanjeer  (1989)  125 min  Action, Crime, Drama     5.8
# 15504  Zulm Ko Jala Doonga  (1988)      NaN                Action     4.6
# 15505                Zulmi  (1999)  129 min         Action, Drama     4.5
# 15506            Zulmi Raj  (2005)      NaN                Action     NaN
# 15507        Zulmi Shikari  (1988)      NaN                Action     NaN
# 15508         Zulm-O-Sitam  (1998)  130 min         Action, Drama     6.2
#
#       Votes           Director                Actor 1              Actor 2  \
# 15499   NaN    Surinder Kapoor            Goga Kapoor        Shakti Kapoor
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15509 entries, 0 to 15508
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      15509 non-null  object
#  1   Year      14981 non-null  object
#  2   Duration  7240 non-null   object
#  3   Genre     13632 non-null  object
#  4   Rating    7919 non-null   float64
#  5   Votes     7920 non-null   object
#  6   Director  14984 non-null  object
#  7   Actor 1   13892 non-null  object
#  8   Actor 2   13125 non-null  object
#  9   Actor 3   12365 non-null  object
# dtypes: float64(1), object(9)
# memory usage: 1.2+ MB

# %%
df.describe()
# Out:
#             Rating
# count  7919.000000
# mean      5.841621
# std       1.381777
# min       1.100000
# 25%       4.900000
# 50%       6.000000
# 75%       6.800000
# max      10.000000

# %% [markdown]
# ### Data filtering and preprocessing

# %%
df.isnull().sum()
# Out:
# Name           0
# Year         528
# Duration    8269
# Genre       1877
# Rating      7590
# Votes       7589
# Director     525
# Actor 1     1617
# Actor 2     2384
# Actor 3     3144
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
round((df.isnull().sum()/len(df))*100,2)
# Out:
# Name         0.00
# Year         3.40
# Duration    53.32
# Genre       12.10
# Rating      48.94
# Votes       48.93
# Director     3.39
# Actor 1     10.43
# Actor 2     15.37
# Actor 3     20.27
# dtype: float64

# %%
attr=df.columns

attr
# Out:
# Index(['Name', 'Year', 'Duration', 'Genre', 'Rating', 'Votes', 'Director',
#        'Actor 1', 'Actor 2', 'Actor 3'],
#       dtype='object')

# %%
unique_genre=df['Genre'].unique()
unique_genre
# Out:
# array(['Drama', 'Drama, Musical', 'Comedy, Romance',
#        'Comedy, Drama, Musical', 'Drama, Romance, War', 'Documentary',
#        'Horror, Mystery, Thriller', 'Action, Crime, Thriller', 'Horror',
#        'Horror, Romance, Thriller', 'Comedy, Drama, Romance', 'Thriller',
#        'Comedy, Drama', nan, 'Comedy, Drama, Fantasy',
#        'Comedy, Drama, Family', 'Crime, Drama, Mystery',
#        'Horror, Thriller', 'Biography', 'Comedy, Horror', 'Action',
#        'Drama, Horror, Mystery', 'Comedy', 'Action, Thriller',
#        'Drama, History', 'Drama, History, Sport',
#        'Horror, Mystery, Romance', 'Horror, Mystery',
#        'Drama, Horror, Romance', 'Action, Drama, History',
#        'Action, Drama, War', 'Comedy, Family',
#        'Adventure, Horror, Mystery', 'Action, Sci-Fi',
#        'Crime, Mystery, Thriller', 'War', 'Sport',
#        'Biography, Drama, History', 'Horror, Romance', 'Crime, Drama',
# ...

# %%
rating=df['Rating'].value_counts()
rating
# Out:
# 6.2     269
# 6.8     264
# 6.5     254
# 6.6     239
# 6.7     227
#        ...
# 9.6       1
# 1.4       1
# 9.7       1
# 10.0      1
# 1.1       1
# Name: Rating, Length: 84, dtype: int64

# %%
df.drop_duplicates(inplace=True)

# %%
attributes=['Name','Year','Duration','Votes','Rating']
df.dropna(subset=attributes,inplace=True)
missing_val=df.isnull().sum()
missing_val
# Out:
# Name          0
# Year          0
# Duration      0
# Genre        31
# Rating        0
# Votes         0
# Director      1
# Actor 1      75
# Actor 2     117
# Actor 3     163
# dtype: int64

# %%
df
# Out:
#                                      Name    Year Duration  \
# 1      #Gadhvi (He thought he was Gandhi)  (2019)  109 min
# 3                                 #Yaaram  (2019)  110 min
# 5                    ...Aur Pyaar Ho Gaya  (1997)  147 min
# 6                               ...Yahaan  (2005)  142 min
# 8                      ?: A Question Mark  (2012)   82 min
# ...                                   ...     ...      ...
# 15493                              Zubaan  (2015)  115 min
# 15494                            Zubeidaa  (2001)  153 min
# 15503                     Zulm Ki Zanjeer  (1989)  125 min
# 15505                               Zulmi  (1999)  129 min
# 15508                        Zulm-O-Sitam  (1998)  130 min
#
#                            Genre  Rating  Votes         Director  \
# 1                          Drama     7.0      8    Gaurav Bakshi
# 3                Comedy, Romance     4.4     35       Ovais Khan
# ...

# %%
movie_with_rating=df[['Name','Rating']]
movie_with_rating
# Out:
#                                      Name  Rating
# 1      #Gadhvi (He thought he was Gandhi)     7.0
# 3                                 #Yaaram     4.4
# 5                    ...Aur Pyaar Ho Gaya     4.7
# 6                               ...Yahaan     7.4
# 8                      ?: A Question Mark     5.6
# ...                                   ...     ...
# 15493                              Zubaan     6.1
# 15494                            Zubeidaa     6.2
# 15503                     Zulm Ki Zanjeer     5.8
# 15505                               Zulmi     4.5
# 15508                        Zulm-O-Sitam     6.2
#
# [5851 rows x 2 columns]

# %%
movies_with_top_rating=movie_with_rating.sort_values('Rating',ascending=False).head(10)
movies_with_top_rating
# Out:
#                       Name  Rating
# 8339       Love Qubool Hai    10.0
# 5410            Half Songs     9.7
# 14222  The Reluctant Crime     9.4
# 5077          Gho Gho Rani     9.4
# 6852                  June     9.4
# 1314          Ashok Vatika     9.3
# 8344          Love Sorries     9.3
# 12673   Secrets of Sinauli     9.3
# 1729              Baikunth     9.3
# 13231           Sindhustan     9.3

# %%
plt.figure(figsize=(8,6))
plt.barh(movies_with_top_rating['Name'],movies_with_top_rating['Rating'])
plt.xlabel("Rating")
plt.ylabel("Movie")
plt.title("Top 10 Highest Rated Movies")
plt.show()

# %%
df['Votes']=pd.to_numeric(df['Votes'],errors='coerce')
plt.figure(figsize=(8,6))
plt.scatter(df['Rating'],df['Votes'])
plt.xlabel('Rating')
plt.ylabel('Votes')
plt.title('Scatter Plot Of Rating vs Votes')
plt.show()

# %%
actors=pd.concat([df['Actor 1'],df['Actor 2'],df['Actor 3']])
actor_count=actors.value_counts().reset_index()
actor_count.columns=['Actor','Number of Movies']

plt.figure(figsize=(8,6))
sns.barplot(data=actor_count.head(10),x='Number of Movies',y='Actor')
plt.xlabel('Number of movies')
plt.ylabel('Actor')
plt.title('Top 10 Actors with Number Of Movies')
plt.show()

# %%
col=['Votes','Rating','Duration','Year']
sns.pairplot(df[col],diag_kind='kde',markers='o',height=3,aspect=1.5)
plt.show()

# %% [markdown]
# ### Feature Engineering

# %%
df_sort=df.sort_values('Votes',ascending=False)
df_sort['Vote_count_percentile']=df_sort['Votes'].rank(pct=True)*100
df_sort.reset_index(drop=True,inplace=True)
df_sort[['Name','Votes','Vote_count_percentile']]
# Out:
#                                       Name  Votes  Vote_count_percentile
# 0     Satyam Shivam Sundaram: Love Sublime  999.0             100.000000
# 1                               Hera Pheri  998.0              99.977689
# 2                              Kurukshetra  996.0              99.955377
# 3                              Dishkiyaoon  986.0              99.933066
# 4                               Kadvi Hawa  985.0              99.899598
# ...                                    ...    ...                    ...
# 5846                                 Ziddi    NaN                    NaN
# 5847                        Zila Ghaziabad    NaN                    NaN
# 5848                                 Zinda    NaN                    NaN
# 5849              Zindagi Na Milegi Dobara    NaN                    NaN
# 5850                              Zubeidaa    NaN                    NaN
#
# [5851 rows x 3 columns]

# %%
df.head()
# Out:
#                                  Name    Year Duration  \
# 1  #Gadhvi (He thought he was Gandhi)  (2019)  109 min
# 3                             #Yaaram  (2019)  110 min
# 5                ...Aur Pyaar Ho Gaya  (1997)  147 min
# 6                           ...Yahaan  (2005)  142 min
# 8                  ?: A Question Mark  (2012)   82 min
#
#                        Genre  Rating  Votes        Director          Actor 1  \
# 1                      Drama     7.0    8.0   Gaurav Bakshi     Rasika Dugal
# 3            Comedy, Romance     4.4   35.0      Ovais Khan          Prateik
# 5     Comedy, Drama, Musical     4.7  827.0    Rahul Rawail       Bobby Deol
# 6        Drama, Romance, War     7.4    NaN  Shoojit Sircar  Jimmy Sheirgill
# 8  Horror, Mystery, Thriller     5.6  326.0   Allyson Patel        Yash Dave
#
#                   Actor 2          Actor 3
# 1          Vivek Ghamande    Arvind Jangid
# 3              Ishita Raj  Siddhant Kapoor
# ...

# %%
df=df.dropna(subset=['Votes'])
df.head()
# Out:
#                                  Name    Year Duration  \
# 1  #Gadhvi (He thought he was Gandhi)  (2019)  109 min
# 3                             #Yaaram  (2019)  110 min
# 5                ...Aur Pyaar Ho Gaya  (1997)  147 min
# 8                  ?: A Question Mark  (2012)   82 min
# 9                            @Andheri  (2014)  116 min
#
#                        Genre  Rating  Votes           Director       Actor 1  \
# 1                      Drama     7.0    8.0      Gaurav Bakshi  Rasika Dugal
# 3            Comedy, Romance     4.4   35.0         Ovais Khan       Prateik
# 5     Comedy, Drama, Musical     4.7  827.0       Rahul Rawail    Bobby Deol
# 8  Horror, Mystery, Thriller     5.6  326.0      Allyson Patel     Yash Dave
# 9    Action, Crime, Thriller     4.0   11.0  Biju Bhaskar Nair     Augustine
#
#                   Actor 2          Actor 3
# 1          Vivek Ghamande    Arvind Jangid
# 3              Ishita Raj  Siddhant Kapoor
# ...

# %% [markdown]
# ### Model Training and Testing

# %%
df['Year']=df['Year'].astype(str)
df['Year']=df['Year'].str.extract('(\d+)').astype(float)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_9316\531310902.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Year']=df['Year'].astype(str)
# C:\Users\DELL\AppData\Local\Temp\ipykernel_9316\531310902.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Year']=df['Year'].str.extract('(\d+)').astype(float)

# %%
df['Duration']=df['Duration'].astype(str)
df['Duration']=df['Duration'].str.extract('(\d+)').astype(float)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_9316\4110861654.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Duration']=df['Duration'].astype(str)
# C:\Users\DELL\AppData\Local\Temp\ipykernel_9316\4110861654.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Duration']=df['Duration'].str.extract('(\d+)').astype(float)

# %%
df=df.drop(columns=['Director','Actor 1','Actor 2','Actor 3'])
df.isnull().sum()
# Out:
# Name         0
# Year         0
# Duration     0
# Genre       31
# Rating       0
# Votes        0
# dtype: int64

# %%
name=df['Name'].values
name
# Out:
# array(['#Gadhvi (He thought he was Gandhi)', '#Yaaram',
#        '...Aur Pyaar Ho Gaya', ..., 'Zulm Ki Zanjeer', 'Zulmi',
#        'Zulm-O-Sitam'], dtype=object)

# %%
df=df.drop(columns=['Name','Genre'])
df
# Out:
#          Year  Duration  Rating  Votes
# 1      2019.0     109.0     7.0    8.0
# 3      2019.0     110.0     4.4   35.0
# 5      1997.0     147.0     4.7  827.0
# 8      2012.0      82.0     5.6  326.0
# 9      2014.0     116.0     4.0   11.0
# ...       ...       ...     ...    ...
# 15492  1975.0     150.0     5.6   33.0
# 15493  2015.0     115.0     6.1  408.0
# 15503  1989.0     125.0     5.8   44.0
# 15505  1999.0     129.0     4.5  655.0
# 15508  1998.0     130.0     6.2   20.0
#
# [4482 rows x 4 columns]

# %%
x=df[['Year','Duration','Votes']]
y=df['Rating']

# %%
from sklearn.model_selection import train_test_split

x_train , x_test , y_train , y_test =train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)
y_pred
# Out:
# array([6.47455333, 5.87626466, 5.98954469, 5.76802222, 5.20665048,
#        6.51220115, 5.70760694, 6.28934458, 5.7304802 , 5.98336626,
#        6.27372398, 5.69577944, 6.39904415, 5.72308117, 5.74498385,
#        6.74160289, 5.9681597 , 6.43042183, 5.07192531, 5.39840646,
#        5.698618  , 6.43520362, 5.81649325, 5.55478705, 5.6834762 ,
#        5.51672402, 5.45851598, 6.00026574, 5.78690806, 5.43304323,
#        5.50875612, 5.72415841, 5.72973789, 5.89947076, 5.74108452,
#        5.49333928, 6.15885198, 5.62509146, 5.70655927, 6.01469806,
#        5.51831398, 5.30180622, 6.04477599, 5.94216554, 5.73019777,
#        6.63832304, 6.23807192, 6.35028087, 5.84431596, 5.97295877,
#        5.78264891, 6.07928565, 5.86248565, 5.59223278, 6.19030719,
#        5.67262379, 5.82582859, 6.23541091, 5.55389107, 5.2245669 ,
#        6.00345351, 6.5819784 , 5.69165759, 5.62587186, 6.31440955,
#        6.5370394 , 6.44098558, 5.92750247, 6.18706865, 6.54311729,
# ...

# %%
y_test
# Out:
# 439      6.3
# 13837    4.4
# 3381     3.3
# 3732     5.8
# 2353     6.9
#         ...
# 7366     5.1
# 10001    5.6
# 13432    4.4
# 14560    5.8
# 12977    4.0
# Name: Rating, Length: 897, dtype: float64

# %%
mae=mean_absolute_error(y_test,y_pred)
rmse=mean_squared_error(y_test,y_pred,squared=False)
r2=r2_score(y_test,y_pred)

print('Mean Abosolute Error: ',mae)
print('Root Mean Squared Error: ',rmse)
print('r2 Score: ',r2)
# Out:
# Mean Abosolute Error:  1.0848311387601357
# Root Mean Squared Error:  1.3484226346477912
# r2 Score:  0.0981216384029091

# %%
xf=df.iloc[:,[0,1,3]]

# %%
y_final=lr.predict(xf)

# %%
final=pd.DataFrame()

# %%
final['Name']=name
final['Rating']=y_final

# %%
final
# Out:
#                                     Name    Rating
# 0     #Gadhvi (He thought he was Gandhi)  5.499252
# 1                                #Yaaram  5.496795
# 2                   ...Aur Pyaar Ho Gaya  5.810165
# 3                     ?: A Question Mark  6.047301
# 4                               @Andheri  5.529851
# ...                                  ...       ...
# 4477                               Zorro  5.995157
# 4478                              Zubaan  5.645463
# 4479                     Zulm Ki Zanjeer  5.975160
# 4480                               Zulmi  5.911292
# 4481                        Zulm-O-Sitam  5.720172
#
# [4482 rows x 2 columns]

# %%
final.to_csv('Task2_Codsoft',index=False)
